# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
# enumerate() method as an alternative way to iterate through the list of cities and retrieve both the index, and the city from the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | liverpool
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | gwadar
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 1 | olafsvik
# Processing Record 10 of Set 1 | novouzensk
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | shimoda
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | byron bay
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | bilibino
# Processing Record 21 of Set 1 | malindi
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | zhezkazgan
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 1 | makakilo city
# Processing Record 31 of Set 1 | valparaiso
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | avera
# Processing Record 35 of Set 1 | alghero
# Processing Record 36 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | nelson bay
# Processing Record 39 of Set 1 | dmitriyevka
# Processing Record 40 of Set 1 | saldanha
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | karasburg
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | tinde
# Processing Record 47 of Set 1 | jimenez
# Processing Record 48 of Set 1 | san patricio
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | aleppo
# Processing Record 6 of Set 2 | broken hill
# Processing Record 7 of Set 2 | vegreville
# Processing Record 8 of Set 2 | leningradskiy
# Processing Record 9 of Set 2 | hasaki
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | berlevag
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | hofn
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | norman wells
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | sao domingos
# Processing Record 18 of Set 2 | banjar
# Processing Record 19 of Set 2 | aktash
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | esperance
# Processing Record 23 of Set 2 | chara
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | tsiroanomandidy
# Processing Record 26 of Set 2 | casma
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 2 | jepara
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | caravelas
# Processing Record 32 of Set 2 | kiunga
# Processing Record 33 of Set 2 | tepetlaoxtoc
# City not found. Skipping...
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | poronaysk
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | touros
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | srednekolymsk
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | saint anthony
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | kruisfontein
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | leh
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | tarakan
# Processing Record 49 of Set 2 | sturgis
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | antofagasta
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | biltine
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | tilichiki
# Processing Record 7 of Set 3 | gushikawa
# Processing Record 8 of Set 3 | bluefields
# Processing Record 9 of Set 3 | goure
# Processing Record 10 of Set 3 | betanzos
# Processing Record 11 of Set 3 | lahaina
# Processing Record 12 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | stornoway
# Processing Record 15 of Set 3 | ixtapa
# Processing Record 16 of Set 3 | kyabe
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | mount gambier
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | port hedland
# Processing Record 22 of Set 3 | nouadhibou
# Processing Record 23 of Set 3 | tura
# Processing Record 24 of Set 3 | kovdor
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | henties bay
# Processing Record 27 of Set 3 | carutapera
# Processing Record 28 of Set 3 | aksarka
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | neryungri
# Processing Record 31 of Set 3 | iwanai
# Processing Record 32 of Set 3 | flinders
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | beringovskiy
# Processing Record 35 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 3 | mahibadhoo
# Processing Record 37 of Set 3 | la seyne-sur-mer
# Processing Record 38 of Set 3 | sorong
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | goundam
# Processing Record 41 of Set 3 | southbridge
# Processing Record 42 of Set 3 | play cu
# City not found. Skipping...
# Processing Record 43 of Set 3 | tongliao
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | muros
# Processing Record 47 of Set 3 | bowen
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | ocotitlan
# Processing Record 1 of Set 4 | lorengau
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | vredendal
# Processing Record 4 of Set 4 | tabou
# Processing Record 5 of Set 4 | vao
# Processing Record 6 of Set 4 | tucupita
# Processing Record 7 of Set 4 | ayagoz
# Processing Record 8 of Set 4 | sao joao da barra
# Processing Record 9 of Set 4 | williamsburg
# Processing Record 10 of Set 4 | kavaratti
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | anklam
# Processing Record 13 of Set 4 | anaconda
# Processing Record 14 of Set 4 | katangli
# Processing Record 15 of Set 4 | guerrero negro
# Processing Record 16 of Set 4 | constitucion
# Processing Record 17 of Set 4 | taunggyi
# Processing Record 18 of Set 4 | sola
# Processing Record 19 of Set 4 | khrustalnyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | huanuco
# Processing Record 21 of Set 4 | bonthe
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 4 | humaita
# Processing Record 25 of Set 4 | young
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | bloemfontein
# Processing Record 28 of Set 4 | laramie
# Processing Record 29 of Set 4 | copiapo
# Processing Record 30 of Set 4 | asfi
# Processing Record 31 of Set 4 | san cristobal
# Processing Record 32 of Set 4 | korla
# Processing Record 33 of Set 4 | souillac
# Processing Record 34 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 4 | la libertad
# Processing Record 36 of Set 4 | yanai
# Processing Record 37 of Set 4 | ewa beach
# Processing Record 38 of Set 4 | dakar
# Processing Record 39 of Set 4 | turukhansk
# Processing Record 40 of Set 4 | chuy
# Processing Record 41 of Set 4 | sassandra
# Processing Record 42 of Set 4 | burnie
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | kenai
# Processing Record 45 of Set 4 | portland
# Processing Record 46 of Set 4 | mau aima
# City not found. Skipping...
# Processing Record 47 of Set 4 | cayenne
# Processing Record 48 of Set 4 | lola
# Processing Record 49 of Set 4 | strezhevoy
# Processing Record 50 of Set 4 | ouallam
# Processing Record 1 of Set 5 | mahebourg
# Processing Record 2 of Set 5 | grand gaube
# Processing Record 3 of Set 5 | la ronge
# Processing Record 4 of Set 5 | aguazul
# Processing Record 5 of Set 5 | hithadhoo
# Processing Record 6 of Set 5 | sakakah
# Processing Record 7 of Set 5 | ormara
# Processing Record 8 of Set 5 | waipawa
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | port macquarie
# Processing Record 11 of Set 5 | kalanguy
# Processing Record 12 of Set 5 | mwense
# Processing Record 13 of Set 5 | puri
# Processing Record 14 of Set 5 | maracai
# Processing Record 15 of Set 5 | gamboula
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | chisec
# Processing Record 18 of Set 5 | kieta
# Processing Record 19 of Set 5 | elizabeth city
# Processing Record 20 of Set 5 | kozhevnikovo
# Processing Record 21 of Set 5 | gornopravdinsk
# Processing Record 22 of Set 5 | luganville
# Processing Record 23 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 5 | san quintin
# Processing Record 25 of Set 5 | korba
# Processing Record 26 of Set 5 | havelock
# Processing Record 27 of Set 5 | north battleford
# Processing Record 28 of Set 5 | luderitz
# Processing Record 29 of Set 5 | matagami
# Processing Record 30 of Set 5 | la crosse
# Processing Record 31 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 5 | kahului
# Processing Record 33 of Set 5 | georgetown
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | tual
# Processing Record 36 of Set 5 | zaterechnyy
# Processing Record 37 of Set 5 | pagudpud
# Processing Record 38 of Set 5 | vardo
# Processing Record 39 of Set 5 | sarkand
# Processing Record 40 of Set 5 | nanortalik
# Processing Record 41 of Set 5 | carahue
# Processing Record 42 of Set 5 | saint-pierre
# Processing Record 43 of Set 5 | shubarshi
# Processing Record 44 of Set 5 | sao lourenco do sul
# Processing Record 45 of Set 5 | rincon
# Processing Record 46 of Set 5 | egvekinot
# Processing Record 47 of Set 5 | hokitika
# Processing Record 48 of Set 5 | diglur
# Processing Record 49 of Set 5 | lompoc
# Processing Record 50 of Set 5 | ribeira grande
# Processing Record 1 of Set 6 | ravar
# Processing Record 2 of Set 6 | nuh
# Processing Record 3 of Set 6 | aklavik
# Processing Record 4 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 6 | vrani
# Processing Record 6 of Set 6 | trinidad
# Processing Record 7 of Set 6 | poopo
# Processing Record 8 of Set 6 | naze
# Processing Record 9 of Set 6 | havoysund
# Processing Record 10 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 6 | port hardy
# Processing Record 12 of Set 6 | sibolga
# Processing Record 13 of Set 6 | ust-tsilma
# Processing Record 14 of Set 6 | bartica
# Processing Record 15 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 6 | nantucket
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | laguna
# Processing Record 19 of Set 6 | dingle
# Processing Record 20 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 21 of Set 6 | caborca
# Processing Record 22 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 6 | grindavik
# Processing Record 24 of Set 6 | talnakh
# Processing Record 25 of Set 6 | dickinson
# Processing Record 26 of Set 6 | olga
# Processing Record 27 of Set 6 | kidal
# Processing Record 28 of Set 6 | tartagal
# Processing Record 29 of Set 6 | yunyang
# Processing Record 30 of Set 6 | siyabuswa
# Processing Record 31 of Set 6 | sinnamary
# Processing Record 32 of Set 6 | andarab
# City not found. Skipping...
# Processing Record 33 of Set 6 | broome
# Processing Record 34 of Set 6 | snezhnogorsk
# Processing Record 35 of Set 6 | katsuura
# Processing Record 36 of Set 6 | abu kamal
# Processing Record 37 of Set 6 | rawson
# Processing Record 38 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 6 | taseyevo
# Processing Record 40 of Set 6 | marienburg
# Processing Record 41 of Set 6 | vila franca do campo
# Processing Record 42 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 6 | avarua
# Processing Record 44 of Set 6 | beaverlodge
# Processing Record 45 of Set 6 | bacungan
# Processing Record 46 of Set 6 | paita
# Processing Record 47 of Set 6 | bandarbeyla
# Processing Record 48 of Set 6 | paragominas
# Processing Record 49 of Set 6 | helong
# Processing Record 50 of Set 6 | skagen
# Processing Record 1 of Set 7 | camacha
# Processing Record 2 of Set 7 | yar-sale
# Processing Record 3 of Set 7 | kiknur
# Processing Record 4 of Set 7 | manzanares
# Processing Record 5 of Set 7 | lasa
# Processing Record 6 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 7 | telimele
# Processing Record 8 of Set 7 | kundiawa
# Processing Record 9 of Set 7 | toropets
# Processing Record 10 of Set 7 | port keats
# Processing Record 11 of Set 7 | adrar
# Processing Record 12 of Set 7 | solofra
# Processing Record 13 of Set 7 | asau
# Processing Record 14 of Set 7 | meulaboh
# Processing Record 15 of Set 7 | anqing
# Processing Record 16 of Set 7 | tamworth
# Processing Record 17 of Set 7 | ostersund
# Processing Record 18 of Set 7 | jucas
# Processing Record 19 of Set 7 | whitefish
# Processing Record 20 of Set 7 | mairana
# Processing Record 21 of Set 7 | mega
# Processing Record 22 of Set 7 | roebourne
# Processing Record 23 of Set 7 | robertsport
# Processing Record 24 of Set 7 | kichera
# Processing Record 25 of Set 7 | kentau
# Processing Record 26 of Set 7 | krasnoselkup
# Processing Record 27 of Set 7 | faya
# Processing Record 28 of Set 7 | kaitangata
# Processing Record 29 of Set 7 | namibe
# Processing Record 30 of Set 7 | saint-augustin
# Processing Record 31 of Set 7 | emerald
# Processing Record 32 of Set 7 | mawlaik
# Processing Record 33 of Set 7 | keti bandar
# Processing Record 34 of Set 7 | bafoulabe
# Processing Record 35 of Set 7 | erzin
# Processing Record 36 of Set 7 | weligama
# Processing Record 37 of Set 7 | north bend
# Processing Record 38 of Set 7 | biak
# Processing Record 39 of Set 7 | lorca
# Processing Record 40 of Set 7 | talara
# Processing Record 41 of Set 7 | tupik
# Processing Record 42 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 7 | college
# Processing Record 44 of Set 7 | mandalgovi
# Processing Record 45 of Set 7 | vila velha
# Processing Record 46 of Set 7 | gizo
# Processing Record 47 of Set 7 | banapur
# Processing Record 48 of Set 7 | erdenet
# Processing Record 49 of Set 7 | nicoya
# Processing Record 50 of Set 7 | beckley
# Processing Record 1 of Set 8 | samarai
# Processing Record 2 of Set 8 | ponta pora
# Processing Record 3 of Set 8 | loubomo
# Processing Record 4 of Set 8 | mackenzie
# Processing Record 5 of Set 8 | udachnyy
# Processing Record 6 of Set 8 | melville
# Processing Record 7 of Set 8 | jelgava
# Processing Record 8 of Set 8 | san lorenzo
# Processing Record 9 of Set 8 | provideniya
# Processing Record 10 of Set 8 | kitgum
# Processing Record 11 of Set 8 | bemidji
# Processing Record 12 of Set 8 | faanui
# Processing Record 13 of Set 8 | itoman
# Processing Record 14 of Set 8 | mujiayingzi
# Processing Record 15 of Set 8 | katobu
# Processing Record 16 of Set 8 | dauphin
# Processing Record 17 of Set 8 | huarmey
# Processing Record 18 of Set 8 | graham
# Processing Record 19 of Set 8 | rocha
# Processing Record 20 of Set 8 | verkhnevilyuysk
# Processing Record 21 of Set 8 | baykit
# Processing Record 22 of Set 8 | hualmay
# Processing Record 23 of Set 8 | ardakan
# Processing Record 24 of Set 8 | bambanglipuro
# Processing Record 25 of Set 8 | gorontalo
# Processing Record 26 of Set 8 | barcelos
# Processing Record 27 of Set 8 | batemans bay
# Processing Record 28 of Set 8 | noumea
# Processing Record 29 of Set 8 | cabedelo
# Processing Record 30 of Set 8 | chilca
# Processing Record 31 of Set 8 | fairbanks
# Processing Record 32 of Set 8 | paamiut
# Processing Record 33 of Set 8 | salalah
# Processing Record 34 of Set 8 | ilula
# Processing Record 35 of Set 8 | harlingen
# Processing Record 36 of Set 8 | hattiesburg
# Processing Record 37 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 8 | morant bay
# Processing Record 39 of Set 8 | necochea
# Processing Record 40 of Set 8 | bollnas
# Processing Record 41 of Set 8 | sao jose de ribamar
# Processing Record 42 of Set 8 | lebork
# Processing Record 43 of Set 8 | klyuchi
# Processing Record 44 of Set 8 | santa isabel
# Processing Record 45 of Set 8 | vestmannaeyjar
# Processing Record 46 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 47 of Set 8 | pisco
# Processing Record 48 of Set 8 | geraldton
# Processing Record 49 of Set 8 | kisangani
# Processing Record 50 of Set 8 | elko
# Processing Record 1 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 9 | hamilton
# Processing Record 3 of Set 9 | saint-joseph
# Processing Record 4 of Set 9 | hambantota
# Processing Record 5 of Set 9 | labuhan
# Processing Record 6 of Set 9 | vallenar
# Processing Record 7 of Set 9 | cascais
# Processing Record 8 of Set 9 | coquimbo
# Processing Record 9 of Set 9 | tahoua
# Processing Record 10 of Set 9 | demerval lobao
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | taicheng
# Processing Record 13 of Set 9 | kudahuvadhoo
# Processing Record 14 of Set 9 | contamana
# Processing Record 15 of Set 9 | taoudenni
# Processing Record 16 of Set 9 | sokoni
# Processing Record 17 of Set 9 | abnub
# Processing Record 18 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 9 | beira
# Processing Record 20 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 21 of Set 9 | codrington
# Processing Record 22 of Set 9 | fortuna
# Processing Record 23 of Set 9 | bubaque
# Processing Record 24 of Set 9 | erdaojiang
# Processing Record 25 of Set 9 | algete
# Processing Record 26 of Set 9 | waterloo
# Processing Record 27 of Set 9 | moree
# Processing Record 28 of Set 9 | union
# Processing Record 29 of Set 9 | ahipara
# Processing Record 30 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 31 of Set 9 | winnemucca
# Processing Record 32 of Set 9 | tabuk
# Processing Record 33 of Set 9 | ilulissat
# Processing Record 34 of Set 9 | chalus
# Processing Record 35 of Set 9 | buraydah
# Processing Record 36 of Set 9 | doboz
# Processing Record 37 of Set 9 | marsa matruh
# Processing Record 38 of Set 9 | hami
# Processing Record 39 of Set 9 | torbay
# Processing Record 40 of Set 9 | neuquen
# Processing Record 41 of Set 9 | camocim
# Processing Record 42 of Set 9 | parkes
# Processing Record 43 of Set 9 | tres arroyos
# Processing Record 44 of Set 9 | omboue
# Processing Record 45 of Set 9 | pangody
# Processing Record 46 of Set 9 | billings
# Processing Record 47 of Set 9 | iqaluit
# Processing Record 48 of Set 9 | novaya bryan
# Processing Record 49 of Set 9 | yuanping
# Processing Record 50 of Set 9 | balabac
# Processing Record 1 of Set 10 | caraballeda
# Processing Record 2 of Set 10 | thyboron
# Processing Record 3 of Set 10 | grenville
# Processing Record 4 of Set 10 | balsas
# Processing Record 5 of Set 10 | chimoio
# Processing Record 6 of Set 10 | quatre cocos
# Processing Record 7 of Set 10 | palauig
# Processing Record 8 of Set 10 | vostok
# Processing Record 9 of Set 10 | karonga
# Processing Record 10 of Set 10 | hammerfest
# Processing Record 11 of Set 10 | kangaatsiaq
# Processing Record 12 of Set 10 | north platte
# Processing Record 13 of Set 10 | yumen
# Processing Record 14 of Set 10 | ryazhsk
# Processing Record 15 of Set 10 | fengcheng
# Processing Record 16 of Set 10 | matamoros
# Processing Record 17 of Set 10 | chardara
# Processing Record 18 of Set 10 | alta floresta
# Processing Record 19 of Set 10 | mocuba
# Processing Record 20 of Set 10 | ust-maya
# Processing Record 21 of Set 10 | camacupa
# Processing Record 22 of Set 10 | gijon
# Processing Record 23 of Set 10 | alpena
# Processing Record 24 of Set 10 | kyren
# Processing Record 25 of Set 10 | kingaroy
# Processing Record 26 of Set 10 | tezpur
# Processing Record 27 of Set 10 | sao felix do xingu
# Processing Record 28 of Set 10 | zyryanka
# Processing Record 29 of Set 10 | hirara
# Processing Record 30 of Set 10 | cherskiy
# Processing Record 31 of Set 10 | linkuva
# Processing Record 32 of Set 10 | svobodnyy
# Processing Record 33 of Set 10 | vostochnyy
# Processing Record 34 of Set 10 | kajaani
# Processing Record 35 of Set 10 | kologriv
# Processing Record 36 of Set 10 | flin flon
# Processing Record 37 of Set 10 | batagay-alyta
# Processing Record 38 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 10 | marovoay
# Processing Record 41 of Set 10 | skelleftea
# Processing Record 42 of Set 10 | christchurch
# Processing Record 43 of Set 10 | monopoli
# Processing Record 44 of Set 10 | ahuimanu
# Processing Record 45 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 10 | oranjemund
# Processing Record 47 of Set 10 | okhotsk
# Processing Record 48 of Set 10 | san roque
# Processing Record 49 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 10 | san ramon
# Processing Record 1 of Set 11 | sainte-rose
# Processing Record 2 of Set 11 | half moon bay
# Processing Record 3 of Set 11 | wilkie
# Processing Record 4 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 5 of Set 11 | lardos
# Processing Record 6 of Set 11 | xining
# Processing Record 7 of Set 11 | ha giang
# Processing Record 8 of Set 11 | delta
# Processing Record 9 of Set 11 | conde
# Processing Record 10 of Set 11 | soyo
# Processing Record 11 of Set 11 | nisia floresta
# Processing Record 12 of Set 11 | verkhnyaya inta
# Processing Record 13 of Set 11 | aswan
# Processing Record 14 of Set 11 | kutum
# Processing Record 15 of Set 11 | holoby
# Processing Record 16 of Set 11 | taua
# Processing Record 17 of Set 11 | manokwari
# Processing Record 18 of Set 11 | vanavara
# Processing Record 19 of Set 11 | finspang
# Processing Record 20 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 11 | koumac
# Processing Record 22 of Set 11 | tobol
# Processing Record 23 of Set 11 | bo
# City not found. Skipping...
# Processing Record 24 of Set 11 | ola
# Processing Record 25 of Set 11 | poshekhonye
# Processing Record 26 of Set 11 | sistranda
# Processing Record 27 of Set 11 | port blair
# Processing Record 28 of Set 11 | pachino
# Processing Record 29 of Set 11 | shanhetun
# Processing Record 30 of Set 11 | ukiah
# Processing Record 31 of Set 11 | oranjestad
# Processing Record 32 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 11 | mathbaria
# Processing Record 34 of Set 11 | sakaiminato
# Processing Record 35 of Set 11 | ketchikan
# Processing Record 36 of Set 11 | margate
# Processing Record 37 of Set 11 | mitzic
# Processing Record 38 of Set 11 | berdigestyakh
# Processing Record 39 of Set 11 | kamaishi
# Processing Record 40 of Set 11 | ust-kut
# Processing Record 41 of Set 11 | maraba
# Processing Record 42 of Set 11 | dorogobuzh
# Processing Record 43 of Set 11 | brae
# Processing Record 44 of Set 11 | joshimath
# Processing Record 45 of Set 11 | yima
# Processing Record 46 of Set 11 | harwich
# Processing Record 47 of Set 11 | chake chake
# Processing Record 48 of Set 11 | nador
# Processing Record 49 of Set 11 | belyy yar
# Processing Record 50 of Set 11 | dawlatabad
# Processing Record 1 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 12 | buarcos
# Processing Record 3 of Set 12 | grand island
# Processing Record 4 of Set 12 | itapolis
# Processing Record 5 of Set 12 | klaksvik
# Processing Record 6 of Set 12 | voh
# Processing Record 7 of Set 12 | pitimbu
# Processing Record 8 of Set 12 | dawei
# Processing Record 9 of Set 12 | riviere-au-renard
# Processing Record 10 of Set 12 | boa vista
# Processing Record 11 of Set 12 | allapalli
# Processing Record 12 of Set 12 | samana
# Processing Record 13 of Set 12 | tokur
# Processing Record 14 of Set 12 | odweyne
# Processing Record 15 of Set 12 | nemuro
# Processing Record 16 of Set 12 | high level
# Processing Record 17 of Set 12 | khuzdar
# Processing Record 18 of Set 12 | eyl
# Processing Record 19 of Set 12 | ust-karsk
# Processing Record 20 of Set 12 | visnes
# Processing Record 21 of Set 12 | pacific grove
# Processing Record 22 of Set 12 | panguna
# Processing Record 23 of Set 12 | hearst
# Processing Record 24 of Set 12 | ji-parana
# City not found. Skipping...
# Processing Record 25 of Set 12 | senanga
# Processing Record 26 of Set 12 | tuatapere
# Processing Record 27 of Set 12 | mackay
# Processing Record 28 of Set 12 | the pas
# Processing Record 29 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 30 of Set 12 | igarka
# Processing Record 31 of Set 12 | hovd
# Processing Record 32 of Set 12 | nuevo progreso
# Processing Record 33 of Set 12 | koping
# Processing Record 34 of Set 12 | itarema
# Processing Record 35 of Set 12 | abalak
# Processing Record 36 of Set 12 | miri
# Processing Record 37 of Set 12 | sungaipenuh
# Processing Record 38 of Set 12 | kolvereid
# Processing Record 39 of Set 12 | santa maria
# Processing Record 40 of Set 12 | ukhta
# Processing Record 41 of Set 12 | methoni
# Processing Record 42 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 12 | coihaique
# Processing Record 44 of Set 12 | kilindoni
# Processing Record 45 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 12 | gweta
# Processing Record 47 of Set 12 | kulhudhuffushi
# Processing Record 48 of Set 12 | kandrian
# Processing Record 49 of Set 12 | pumiao
# Processing Record 50 of Set 12 | eskisehir
# Processing Record 1 of Set 13 | hanmer springs
# Processing Record 2 of Set 13 | pangkalanbuun
# Processing Record 3 of Set 13 | troitskoye
# Processing Record 4 of Set 13 | the valley
# Processing Record 5 of Set 13 | danville
# Processing Record 6 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 13 | bela vista
# Processing Record 8 of Set 13 | nautla
# Processing Record 9 of Set 13 | roald
# Processing Record 10 of Set 13 | dickson
# Processing Record 11 of Set 13 | smithers
# Processing Record 12 of Set 13 | mecca
# Processing Record 13 of Set 13 | zhetybay
# City not found. Skipping...
# Processing Record 14 of Set 13 | isangel
# Processing Record 15 of Set 13 | kaduqli
# Processing Record 16 of Set 13 | elban
# Processing Record 17 of Set 13 | lata
# Processing Record 18 of Set 13 | augusto correa
# Processing Record 19 of Set 13 | huangmei
# Processing Record 20 of Set 13 | abengourou
# Processing Record 21 of Set 13 | deputatskiy
# Processing Record 22 of Set 13 | sao miguel do araguaia
# Processing Record 23 of Set 13 | port hawkesbury
# Processing Record 24 of Set 13 | morro bay
# Processing Record 25 of Set 13 | buchanan
# Processing Record 26 of Set 13 | adre
# Processing Record 27 of Set 13 | chiredzi
# Processing Record 28 of Set 13 | tete
# Processing Record 29 of Set 13 | victor harbor
# Processing Record 30 of Set 13 | rajauri
# Processing Record 31 of Set 13 | ambilobe
# Processing Record 32 of Set 13 | chifeng
# Processing Record 33 of Set 13 | bintulu
# Processing Record 34 of Set 13 | gat
# Processing Record 35 of Set 13 | acapulco
# Processing Record 36 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 13 | lodja
# Processing Record 38 of Set 13 | taltal
# Processing Record 39 of Set 13 | polson
# Processing Record 40 of Set 13 | eston
# Processing Record 41 of Set 13 | ostrovnoy
# Processing Record 42 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 13 | alcaniz
# Processing Record 44 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 45 of Set 13 | yerbogachen
# Processing Record 46 of Set 13 | alice springs
# Processing Record 47 of Set 13 | nishihara
# Processing Record 48 of Set 13 | owasso
# Processing Record 49 of Set 13 | bure
# Processing Record 50 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 14 | maceio
# Processing Record 2 of Set 14 | phek
# Processing Record 3 of Set 14 | mugur-aksy
# Processing Record 4 of Set 14 | te anau
# Processing Record 5 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 14 | zhigansk
# Processing Record 7 of Set 14 | san vicente
# Processing Record 8 of Set 14 | marau
# Processing Record 9 of Set 14 | kyzyl
# Processing Record 10 of Set 14 | kuytun
# Processing Record 11 of Set 14 | vilhena
# Processing Record 12 of Set 14 | castelo branco
# Processing Record 13 of Set 14 | lubango
# Processing Record 14 of Set 14 | erenhot
# Processing Record 15 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 16 of Set 14 | rylsk
# Processing Record 17 of Set 14 | kambove
# Processing Record 18 of Set 14 | vendome
# Processing Record 19 of Set 14 | levittown
# Processing Record 20 of Set 14 | cusco
# Processing Record 21 of Set 14 | qaqortoq
# Processing Record 22 of Set 14 | riyadh
# Processing Record 23 of Set 14 | roma
# Processing Record 24 of Set 14 | penzance
# Processing Record 25 of Set 14 | guasdualito
# Processing Record 26 of Set 14 | laurel
# Processing Record 27 of Set 14 | esterhazy
# Processing Record 28 of Set 14 | mount isa
# Processing Record 29 of Set 14 | daman
# Processing Record 30 of Set 14 | luau
# Processing Record 31 of Set 14 | yilan
# Processing Record 32 of Set 14 | mehamn
# Processing Record 33 of Set 14 | fort nelson
# Processing Record 34 of Set 14 | yatou
# Processing Record 35 of Set 14 | gondanglegi
# Processing Record 36 of Set 14 | rio tercero
# Processing Record 37 of Set 14 | nabinagar
# Processing Record 38 of Set 14 | berezovyy
# Processing Record 39 of Set 14 | peleduy
# Processing Record 40 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 14 | canavieiras
# Processing Record 42 of Set 14 | berbera
# Processing Record 43 of Set 14 | luxor
# Processing Record 44 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 45 of Set 14 | quzhou
# Processing Record 46 of Set 14 | bayangol
# Processing Record 47 of Set 14 | rio verde de mato grosso
# Processing Record 48 of Set 14 | inhambane
# Processing Record 49 of Set 14 | presidencia roque saenz pena
# Processing Record 50 of Set 14 | lac du bonnet
# Processing Record 1 of Set 15 | eenhana
# Processing Record 2 of Set 15 | socorro
# Processing Record 3 of Set 15 | alofi
# Processing Record 4 of Set 15 | suoyarvi
# Processing Record 5 of Set 15 | kankan
# Processing Record 6 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 15 | payo
# Processing Record 8 of Set 15 | inuvik
# Processing Record 9 of Set 15 | hendaye
# Processing Record 10 of Set 15 | ribeira brava
# Processing Record 11 of Set 15 | tessalit
# Processing Record 12 of Set 15 | baijiantan
# Processing Record 13 of Set 15 | dhidhdhoo
# Processing Record 14 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 15 | dunedin
# Processing Record 16 of Set 15 | cap malheureux
# Processing Record 17 of Set 15 | zhangye
# Processing Record 18 of Set 15 | oleksandrivka
# Processing Record 19 of Set 15 | mezen
# Processing Record 20 of Set 15 | badou
# Processing Record 21 of Set 15 | beloha
# Processing Record 22 of Set 15 | bogande
# Processing Record 23 of Set 15 | asosa
# Processing Record 24 of Set 15 | okha
# Processing Record 25 of Set 15 | tommot
# Processing Record 26 of Set 15 | san andres
# Processing Record 27 of Set 15 | kimbe
# Processing Record 28 of Set 15 | malyye derbety
# Processing Record 29 of Set 15 | baoma
# Processing Record 30 of Set 15 | mingshui
# Processing Record 31 of Set 15 | aksha
# Processing Record 32 of Set 15 | sompeta
# Processing Record 33 of Set 15 | luan
# Processing Record 34 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 15 | talas
# Processing Record 36 of Set 15 | grants pass
# Processing Record 37 of Set 15 | jacareacanga
# Processing Record 38 of Set 15 | davila
# Processing Record 39 of Set 15 | gaoua
# Processing Record 40 of Set 15 | la rioja
# Processing Record 41 of Set 15 | araouane
# Processing Record 42 of Set 15 | marsabit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Liverpool',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 41.61,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'GB',
#   'Weather Description': 'few clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 29.71,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15,
#   'Country': 'RU',
#   'Weather Description': 'snow'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 61.48,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Country': 'NZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.86,
#   'Humidity': 75,
#   'Cloudiness': 10,
#   'Wind Speed': 14.85,
#   'Country': 'PF',
#   'Weather Description': 'clear sky'},
#  {'City': 'Gwadar',
#   'Lat': 25.1216,
#   'Lng': 62.3254,
#   'Max Temp': 76.3,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 13.62,
#   'Country': 'PK',
#   'Weather Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 81.1,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -10.28,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 5.93,
#   'Country': 'GL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 35.19,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 27.85,
#   'Country': 'IS',
#   'Weather Description': 'light snow'},
#  {'City': 'Novouzensk',
#   'Lat': 50.4592,
#   'Lng': 48.1431,
#   'Max Temp': 31.8,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 16.84,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -18.58,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Weather Description': 'few clouds'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 42.1,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Country': 'JP',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 10.56,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 11.68,
#   'Country': 'GL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 61.81,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Country': 'NZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Byron Bay',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 79.05,
#   'Humidity': 86,
#   'Cloudiness': 81,
#   'Wind Speed': 8.79,
#   'Country': 'AU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 67.12,
#   'Humidity': 59,
#   'Cloudiness': 38,
#   'Wind Speed': 8.57,
#   'Country': 'US',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 84.04,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 20.51,
#   'Country': 'AU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 0,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Malindi',
#   'Lat': -3.2175,
#   'Lng': 40.1191,
#   'Max Temp': 81.9,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 13.56,
#   'Country': 'KE',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 87.22,
#   'Humidity': 66,
#   'Cloudiness': 71,
#   'Wind Speed': 14.38,
#   'Country': 'MU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 76.73,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Country': 'PF',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 81.9,
#   'Humidity': 60,
#   'Cloudiness': 41,
#   'Wind Speed': 15.88,
#   'Country': 'ZA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Zhezkazgan',
#   'Lat': 47.8043,
#   'Lng': 67.7144,
#   'Max Temp': 19.38,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 17.9,
#   'Country': 'KZ',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 41.11,
#   'Humidity': 70,
#   'Cloudiness': 86,
#   'Wind Speed': 12.53,
#   'Country': 'CL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 77.22,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Makakilo City',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 72.68,
#   'Humidity': 70,
#   'Cloudiness': 22,
#   'Wind Speed': 9.04,
#   'Country': 'US',
#   'Weather Description': 'few clouds'},
#  {'City': 'Valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 65.48,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -5.66,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 29.71,
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 5.91,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Alghero',
#   'Lat': 40.5589,
#   'Lng': 8.3181,
#   'Max Temp': 51.89,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'IT',
#   'Weather Description': 'few clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.26,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'AR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nelson Bay',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 80.1,
#   'Humidity': 72,
#   'Cloudiness': 62,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Dmitriyevka',
#   'Lat': 54.75,
#   'Lng': 55.3333,
#   'Max Temp': 11.75,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 10.2,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 71.1,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 10.33,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 78.28,
#   'Humidity': 59,
#   'Cloudiness': 53,
#   'Wind Speed': 17.11,
#   'Country': 'ZA',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Karasburg',
#   'Lat': -28.0167,
#   'Lng': 18.75,
#   'Max Temp': 87.46,
#   'Humidity': 29,
#   'Cloudiness': 94,
#   'Wind Speed': 12.41,
#   'Country': 'NA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 76.87,
#   'Humidity': 43,
#   'Cloudiness': 14,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 63.23,
#   'Humidity': 37,
#   'Cloudiness': 5,
#   'Wind Speed': 7,
#   'Country': 'PT',
#   'Weather Description': 'clear sky'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 74.86,
#   'Humidity': 95,
#   'Cloudiness': 82,
#   'Wind Speed': 4.56,
#   'Country': 'BR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tinde',
#   'Lat': -3.8833,
#   'Lng': 33.2,
#   'Max Temp': 74.12,
#   'Humidity': 67,
#   'Cloudiness': 88,
#   'Wind Speed': 6.67,
#   'Country': 'TZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jimenez',
#   'Lat': 28.3333,
#   'Lng': -105.4,
#   'Max Temp': 50.92,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 7.05,
#   'Country': 'MX',
#   'Weather Description': 'clear sky'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 53.44,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 82.42,
#   'Humidity': 70,
#   'Cloudiness': 2,
#   'Wind Speed': 14.99,
#   'Country': 'AU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 23.74,
#   'Humidity': 79,
#   'Cloudiness': 5,
#   'Wind Speed': 8.37,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 81.16,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 13.85,
#   'Country': 'TO',
#   'Weather Description': 'light rain'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 25.63,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Country': 'RU',
#   'Weather Description': 'snow'},
#  {'City': 'Aleppo',
#   'Lat': 36.25,
#   'Lng': 37.5,
#   'Max Temp': 43.36,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 12.8,
#   'Country': 'SY',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 85.82,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vegreville',
#   'Lat': 53.5001,
#   'Lng': -112.0518,
#   'Max Temp': 22.37,
#   'Humidity': 88,
#   'Cloudiness': 92,
#   'Wind Speed': 6.15,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -7.19,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 45,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 7.49,
#   'Country': 'JP',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 8.82,
#   'Humidity': 76,
#   'Cloudiness': 87,
#   'Wind Speed': 7.81,
#   'Country': 'GL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 26.47,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 12.41,
#   'Country': 'NO',
#   'Weather Description': 'light snow'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -2.7,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Country': 'GL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 32.63,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'IS',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 6.51,
#   'Humidity': 53,
#   'Cloudiness': 37,
#   'Wind Speed': 18.01,
#   'Country': 'US',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -19.62,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 81.1,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 7.7,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Sao Domingos',
#   'Lat': -13.3983,
#   'Lng': -46.3183,
#   'Max Temp': 66.25,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.87,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Banjar',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 87.66,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Aktash',
#   'Lat': 50.3,
#   'Lng': 87.7333,
#   'Max Temp': 8.26,
#   'Humidity': 70,
#   'Cloudiness': 24,
#   'Wind Speed': 3.74,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 72.9,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Country': 'EC',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 82.2,
#   'Humidity': 50,
#   'Cloudiness': 18,
#   'Wind Speed': 25.32,
#   'Country': 'AU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Chara',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': -13.59,
#   'Humidity': 94,
#   'Cloudiness': 24,
#   'Wind Speed': 1.36,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 12.56,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tsiroanomandidy',
#   'Lat': -18.7667,
#   'Lng': 46.0333,
#   'Max Temp': 83.37,
#   'Humidity': 59,
#   'Cloudiness': 38,
#   'Wind Speed': 1.45,
#   'Country': 'MG',
#   'Weather Description': 'light rain'},
#  {'City': 'Casma',
#   'Lat': -41.0082,
#   'Lng': -73.1244,
#   'Max Temp': 56.48,
#   'Humidity': 99,
#   'Cloudiness': 89,
#   'Wind Speed': 4.16,
#   'Country': 'CL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -19.26,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.84,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jepara',
#   'Lat': -5.1695,
#   'Lng': 105.7044,
#   'Max Temp': 85.73,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Country': 'ID',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 46.35,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 74.88,
#   'Humidity': 87,
#   'Cloudiness': 19,
#   'Wind Speed': 7.31,
#   'Country': 'BR',
#   'Weather Description': 'few clouds'},
#  {'City': 'Kiunga',
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp': 76.68,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.19,
#   'Country': 'PG',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 68.25,
#   'Humidity': 83,
#   'Cloudiness': 46,
#   'Wind Speed': 8.01,
#   'Country': 'US',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Poronaysk',
#   'Lat': 49.2167,
#   'Lng': 143.1167,
#   'Max Temp': 2.8,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.95,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 78.91,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 11.27,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 77.7,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 9.17,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 72.18,
#   'Humidity': 63,
#   'Cloudiness': 36,
#   'Wind Speed': 11.99,
#   'Country': 'BR',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -28.71,
#   'Humidity': 100,
#   'Cloudiness': 80,
#   'Wind Speed': 1.86,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 68.18,
#   'Humidity': 58,
#   'Cloudiness': 64,
#   'Wind Speed': 1.99,
#   'Country': 'HK',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 19.6,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 61.34,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 78.89,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 9.26,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -12.28,
#   'Humidity': 99,
#   'Cloudiness': 44,
#   'Wind Speed': 1.52,
#   'Country': 'RU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Leh',
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 9.9,
#   'Humidity': 75,
#   'Cloudiness': 42,
#   'Wind Speed': 1.57,
#   'Country': 'IN',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 7.07,
#   'Country': 'PG',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -12.23,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tarakan',
#   'Lat': 3.3,
#   'Lng': 117.6333,
#   'Max Temp': 87.3,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'ID',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sturgis',
#   'Lat': 41.7992,
#   'Lng': -85.4192,
#   'Max Temp': 17.67,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -25.73,
#   'Humidity': 93,
#   'Cloudiness': 66,
#   'Wind Speed': 1.95,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 63.68,
#   'Humidity': 82,
#   'Cloudiness': 59,
#   'Wind Speed': 3.22,
#   'Country': 'CL',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -5.96,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 11.21,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Biltine',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 67.55,
#   'Humidity': 15,
#   'Cloudiness': 4,
#   'Wind Speed': 12.84,
#   'Country': 'TD',
#   'Weather Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.44,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 18.14,
#   'Country': 'KI',
#   'Weather Description': 'light rain'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 81.25,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.34,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 16.88,
#   'Humidity': 71,
#   'Cloudiness': 97,
#   'Wind Speed': 17.25,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gushikawa',
#   'Lat': 26.3544,
#   'Lng': 127.8686,
#   'Max Temp': 61.83,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'JP',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bluefields',
#   'Lat': 12.0137,
#   'Lng': -83.7635,
#   'Max Temp': 71.06,
#   'Humidity': 86,
#   'Cloudiness': 47,
#   'Wind Speed': 6.93,
#   'Country': 'NI',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Goure',
#   'Lat': 13.9835,
#   'Lng': 10.2704,
#   'Max Temp': 68.02,
#   'Humidity': 16,
#   'Cloudiness': 3,
#   'Wind Speed': 16.26,
#   'Country': 'NE',
#   'Weather Description': 'clear sky'},
#  {'City': 'Betanzos',
#   'Lat': 43.2804,
#   'Lng': -8.2147,
#   'Max Temp': 45.09,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'ES',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lahaina',
#   'Lat': 20.8783,
#   'Lng': -156.6825,
#   'Max Temp': 73.81,
#   'Humidity': 81,
#   'Cloudiness': 26,
#   'Wind Speed': 6.64,
#   'Country': 'US',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 69.51,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 9.69,
#   'Country': 'MX',
#   'Weather Description': 'few clouds'},
#  {'City': 'Stornoway',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 39.16,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'GB',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 68.23,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 3.51,
#   'Country': 'MX',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kyabe',
#   'Lat': 9.4515,
#   'Lng': 18.9449,
#   'Max Temp': 79.65,
#   'Humidity': 15,
#   'Cloudiness': 15,
#   'Wind Speed': 8.16,
#   'Country': 'TD',
#   'Weather Description': 'few clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -18.49,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 7.63,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 70.86,
#   'Humidity': 74,
#   'Cloudiness': 9,
#   'Wind Speed': 11.03,
#   'Country': 'AU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 54.63,
#   'Humidity': 89,
#   'Cloudiness': 12,
#   'Wind Speed': 6.35,
#   'Country': 'CL',
#   'Weather Description': 'few clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 79.29,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 11.77,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 89.65,
#   'Humidity': 66,
#   'Cloudiness': 31,
#   'Wind Speed': 27.63,
#   'Country': 'AU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 62.58,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 19.89,
#   'Country': 'MR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 68.13,
#   'Humidity': 35,
#   'Cloudiness': 36,
#   'Wind Speed': 4.72,
#   'Country': 'IN',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kovdor',
#   'Lat': 67.5662,
#   'Lng': 30.4758,
#   'Max Temp': -5.15,
#   'Humidity': 100,
#   'Cloudiness': 98,
#   'Wind Speed': 2.13,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 49.53,
#   'Humidity': 78,
#   'Cloudiness': 64,
#   'Wind Speed': 8.84,
#   'Country': 'CL',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 65.86,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 6.24,
#   'Country': 'NA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 73.33,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.96,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Aksarka',
#   'Lat': 66.5606,
#   'Lng': 67.7975,
#   'Max Temp': -12.6,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 6.51,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 6.8,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 15.86,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Neryungri',
#   'Lat': 56.6709,
#   'Lng': 124.6491,
#   'Max Temp': -5.53,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.43,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Iwanai',
#   'Lat': 42.9744,
#   'Lng': 140.5089,
#   'Max Temp': 17.92,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 15.97,
#   'Country': 'JP',
#   'Weather Description': 'light snow'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 81.21,
#   'Humidity': 78,
#   'Cloudiness': 82,
#   'Wind Speed': 4.45,
#   'Country': 'AU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 9.72,
#   'Humidity': 10,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': -13.11,
#   'Humidity': 100,
#   'Cloudiness': 86,
#   'Wind Speed': 2.68,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mahibadhoo',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 82.17,
#   'Humidity': 70,
#   'Cloudiness': 57,
#   'Wind Speed': 9.89,
#   'Country': 'MV',
#   'Weather Description': 'broken clouds'},
#  {'City': 'La Seyne-Sur-Mer',
#   'Lat': 43.0982,
#   'Lng': 5.8847,
#   'Max Temp': 43.93,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 5.03,
#   'Country': 'FR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Sorong',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 82.33,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 8.79,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 75.67,
#   'Humidity': 71,
#   'Cloudiness': 16,
#   'Wind Speed': 12.91,
#   'Country': 'BB',
#   'Weather Description': 'few clouds'},
#  {'City': 'Goundam',
#   'Lat': 16.4145,
#   'Lng': -3.6708,
#   'Max Temp': 68.43,
#   'Humidity': 15,
#   'Cloudiness': 2,
#   'Wind Speed': 12.28,
#   'Country': 'ML',
#   'Weather Description': 'clear sky'},
#  {'City': 'Southbridge',
#   'Lat': 42.0751,
#   'Lng': -72.0334,
#   'Max Temp': 10.78,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tongliao',
#   'Lat': 43.6125,
#   'Lng': 122.2653,
#   'Max Temp': 20.41,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'CN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 57.42,
#   'Humidity': 69,
#   'Cloudiness': 10,
#   'Wind Speed': 18.61,
#   'Country': 'PT',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -6.36,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 16.62,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 49.84,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'ES',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 83.73,
#   'Humidity': 70,
#   'Cloudiness': 5,
#   'Wind Speed': 16.33,
#   'Country': 'AU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 87.35,
#   'Humidity': 73,
#   'Cloudiness': 18,
#   'Wind Speed': 12.44,
#   'Country': 'RE',
#   'Weather Description': 'few clouds'},
#  {'City': 'Ocotitlan',
#   'Lat': 19.2333,
#   'Lng': -99.6167,
#   'Max Temp': 53.31,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MX',
#   'Weather Description': 'few clouds'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.41,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 10.18,
#   'Country': 'PG',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 67.3,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Country': 'TL',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Vredendal',
#   'Lat': -31.6683,
#   'Lng': 18.5012,
#   'Max Temp': 91.69,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 4.21,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tabou',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 77.74,
#   'Humidity': 88,
#   'Cloudiness': 54,
#   'Wind Speed': 4.99,
#   'Country': 'CI',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 80.04,
#   'Humidity': 86,
#   'Cloudiness': 33,
#   'Wind Speed': 16.31,
#   'Country': 'NC',
#   'Weather Description': 'light rain'},
#  {'City': 'Tucupita',
#   'Lat': 9.0622,
#   'Lng': -62.051,
#   'Max Temp': 66.47,
#   'Humidity': 95,
#   'Cloudiness': 94,
#   'Wind Speed': 2.48,
#   'Country': 'VE',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ayagoz',
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': 21.06,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.74,
#   'Country': 'KZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 74.89,
#   'Humidity': 90,
#   'Cloudiness': 85,
#   'Wind Speed': 4.65,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Williamsburg',
#   'Lat': 37.2707,
#   'Lng': -76.7075,
#   'Max Temp': 24.75,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 81.79,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 9.33,
#   'Country': 'IN',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 91.24,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 21.85,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Anklam',
#   'Lat': 53.8564,
#   'Lng': 13.6897,
#   'Max Temp': 42.26,
#   'Humidity': 66,
#   'Cloudiness': 76,
#   'Wind Speed': 32.44,
#   'Country': 'DE',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Anaconda',
#   'Lat': 46.1285,
#   'Lng': -112.9423,
#   'Max Temp': 31.77,
#   'Humidity': 65,
#   'Cloudiness': 94,
#   'Wind Speed': 7.25,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Katangli',
#   'Lat': 51.7102,
#   'Lng': 143.2326,
#   'Max Temp': -0.11,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 59.77,
#   'Humidity': 72,
#   'Cloudiness': 30,
#   'Wind Speed': 11.39,
#   'Country': 'MX',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 56.48,
#   'Humidity': 92,
#   'Cloudiness': 6,
#   'Wind Speed': 5.61,
#   'Country': 'CL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Taunggyi',
#   'Lat': 20.7833,
#   'Lng': 97.0333,
#   'Max Temp': 72.82,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 9.46,
#   'Country': 'MM',
#   'Weather Description': 'clear sky'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 81.95,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 17.81,
#   'Country': 'VU',
#   'Weather Description': 'light rain'},
#  {'City': 'Huanuco',
#   'Lat': -9.9329,
#   'Lng': -76.2415,
#   'Max Temp': 63.73,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Country': 'PE',
#   'Weather Description': 'light rain'},
#  {'City': 'Bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 75.33,
#   'Humidity': 78,
#   'Cloudiness': 77,
#   'Wind Speed': 2.64,
#   'Country': 'SL',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 73.74,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 10.78,
#   'Country': 'AU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Humaita',
#   'Lat': -7.5061,
#   'Lng': -63.0208,
#   'Max Temp': 71.51,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.92,
#   'Country': 'BR',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Young',
#   'Lat': -32.6833,
#   'Lng': -57.6333,
#   'Max Temp': 60.48,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 8.14,
#   'Country': 'UY',
#   'Weather Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 8.44,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'SJ',
#   'Weather Description': 'few clouds'},
#  {'City': 'Bloemfontein',
#   'Lat': -29.1211,
#   'Lng': 26.214,
#   'Max Temp': 76.28,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 10,
#   'Country': 'ZA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Laramie',
#   'Lat': 41.3114,
#   'Lng': -105.5911,
#   'Max Temp': 29.95,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Copiapo',
#   'Lat': -27.3667,
#   'Lng': -70.3333,
#   'Max Temp': 59.32,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 2.08,
#   'Country': 'CL',
#   'Weather Description': 'clear sky'},
#  {'City': 'Asfi',
#   'Lat': 32.2994,
#   'Lng': -9.2372,
#   'Max Temp': 61.14,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 9.08,
#   'Country': 'MA',
#   'Weather Description': 'clear sky'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 62.22,
#   'Humidity': 90,
#   'Cloudiness': 78,
#   'Wind Speed': 3.38,
#   'Country': 'VE',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 32.18,
#   'Humidity': 34,
#   'Cloudiness': 93,
#   'Wind Speed': 3.94,
#   'Country': 'CN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 87.37,
#   'Humidity': 65,
#   'Cloudiness': 89,
#   'Wind Speed': 14.65,
#   'Country': 'MU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'La Libertad',
#   'Lat': -2.2333,
#   'Lng': -80.9,
#   'Max Temp': 74.52,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21,
#   'Country': 'EC',
#   'Weather Description': 'light rain'},
#  {'City': 'Yanai',
#   'Lat': 33.9667,
#   'Lng': 132.1167,
#   'Max Temp': 48.2,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 5.55,
#   'Country': 'JP',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ewa Beach',
#   'Lat': 21.3156,
#   'Lng': -158.0072,
#   'Max Temp': 74.08,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 8.99,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Dakar',
#   'Lat': 14.6937,
#   'Lng': -17.4441,
#   'Max Temp': 67.08,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 21.21,
#   'Country': 'SN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': 1.99,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 65.52,
#   'Humidity': 79,
#   'Cloudiness': 49,
#   'Wind Speed': 3.71,
#   'Country': 'UY',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sassandra',
#   'Lat': 4.95,
#   'Lng': -6.0833,
#   'Max Temp': 77.74,
#   'Humidity': 87,
#   'Cloudiness': 22,
#   'Wind Speed': 2.91,
#   'Country': 'CI',
#   'Weather Description': 'few clouds'},
#  {'City': 'Burnie',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 72.95,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 5.86,
#   'Country': 'AU',
#   'Weather Description': 'clear sky'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 35.49,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 19.49,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 41.38,
#   'Humidity': 79,
#   'Cloudiness': 94,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 78.1,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'GF',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lola',
#   'Lat': 7.8,
#   'Lng': -8.5333,
#   'Max Temp': 67.75,
#   'Humidity': 47,
#   'Cloudiness': 62,
#   'Wind Speed': 1.12,
#   'Country': 'GN',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Strezhevoy',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': 8.58,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.29,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ouallam',
#   'Lat': 14.3188,
#   'Lng': 2.0866,
#   'Max Temp': 67.87,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 16.71,
#   'Country': 'NE',
#   'Weather Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 87.26,
#   'Humidity': 66,
#   'Cloudiness': 77,
#   'Wind Speed': 14.09,
#   'Country': 'MU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 87.39,
#   'Humidity': 57,
#   'Cloudiness': 52,
#   'Wind Speed': 11.01,
#   'Country': 'MU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 13.24,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.48,
#   'Country': 'CA',
#   'Weather Description': 'light snow'},
#  {'City': 'Aguazul',
#   'Lat': 5.1728,
#   'Lng': -72.5471,
#   'Max Temp': 76.91,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Country': 'CO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.66,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'MV',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 51.55,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 13.18,
#   'Country': 'SA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ormara',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 73.6,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 11.77,
#   'Country': 'PK',
#   'Weather Description': 'clear sky'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 62.46,
#   'Humidity': 90,
#   'Cloudiness': 44,
#   'Wind Speed': 5.5,
#   'Country': 'NZ',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 76.89,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.95,
#   'Country': 'AU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kalanguy',
#   'Lat': 51.0167,
#   'Lng': 116.5167,
#   'Max Temp': -0.17,
#   'Humidity': 94,
#   'Cloudiness': 21,
#   'Wind Speed': 3.31,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Mwense',
#   'Lat': -10.3845,
#   'Lng': 28.698,
#   'Max Temp': 67.71,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.74,
#   'Country': 'ZM',
#   'Weather Description': 'light rain'},
#  {'City': 'Puri',
#   'Lat': 19.8,
#   'Lng': 85.85,
#   'Max Temp': 79.32,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 6.2,
#   'Country': 'IN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Maracai',
#   'Lat': -22.6106,
#   'Lng': -50.6672,
#   'Max Temp': 69.19,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gamboula',
#   'Lat': 4.1178,
#   'Lng': 15.1393,
#   'Max Temp': 79.86,
#   'Humidity': 17,
#   'Cloudiness': 96,
#   'Wind Speed': 8.55,
#   'Country': 'CF',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': -2.83,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Chisec',
#   'Lat': 15.8167,
#   'Lng': -90.2833,
#   'Max Temp': 61.43,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'GT',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kieta',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 80.8,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Country': 'PG',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Elizabeth City',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 26.02,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kozhevnikovo',
#   'Lat': 56.2589,
#   'Lng': 83.9714,
#   'Max Temp': 15.26,
#   'Humidity': 87,
#   'Cloudiness': 98,
#   'Wind Speed': 5.1,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gornopravdinsk',
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 14,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Luganville',
#   'Lat': -15.5333,
#   'Lng': 167.1667,
#   'Max Temp': 77.65,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Country': 'VU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 57.29,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 6.85,
#   'Country': 'MX',
#   'Weather Description': 'clear sky'},
#  {'City': 'Korba',
#   'Lat': 22.35,
#   'Lng': 82.6833,
#   'Max Temp': 79.65,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 5.91,
#   'Country': 'IN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 26.92,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'North Battleford',
#   'Lat': 52.7834,
#   'Lng': -108.2847,
#   'Max Temp': 27.41,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 67.93,
#   'Humidity': 77,
#   'Cloudiness': 37,
#   'Wind Speed': 13.94,
#   'Country': 'NA',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Matagami',
#   'Lat': 49.7502,
#   'Lng': -77.6328,
#   'Max Temp': -5.69,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'La Crosse',
#   'Lat': 43.8014,
#   'Lng': -91.2396,
#   'Max Temp': 19.6,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 73.85,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 93.13,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'MY',
#   'Weather Description': 'few clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 68.88,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 21.99,
#   'Country': 'AR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 84.25,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 16.82,
#   'Country': 'ID',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Zaterechnyy',
#   'Lat': 44.7931,
#   'Lng': 45.2097,
#   'Max Temp': 38.12,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pagudpud',
#   'Lat': 18.5616,
#   'Lng': 120.7868,
#   'Max Temp': 74.98,
#   'Humidity': 85,
#   'Cloudiness': 74,
#   'Wind Speed': 12.46,
#   'Country': 'PH',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 25.57,
#   'Humidity': 78,
#   'Cloudiness': 92,
#   'Wind Speed': 5.97,
#   'Country': 'NO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sarkand',
#   'Lat': 45.41,
#   'Lng': 79.9186,
#   'Max Temp': 31.08,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'KZ',
#   'Weather Description': 'light snow'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 10.9,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.28,
#   'Country': 'GL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Carahue',
#   'Lat': -38.7,
#   'Lng': -73.1667,
#   'Max Temp': 55.6,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.7,
#   'Country': 'CL',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 87.44,
#   'Humidity': 66,
#   'Cloudiness': 14,
#   'Wind Speed': 24.16,
#   'Country': 'RE',
#   'Weather Description': 'few clouds'},
#  {'City': 'Shubarshi',
#   'Lat': 48.5872,
#   'Lng': 57.1869,
#   'Max Temp': 26.67,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 11.83,
#   'Country': 'KZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sao Lourenco Do Sul',
#   'Lat': -31.3653,
#   'Lng': -51.9783,
#   'Max Temp': 58.89,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 8.14,
#   'Country': 'BR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Rincon',
#   'Lat': 32.296,
#   'Lng': -81.2354,
#   'Max Temp': 33.85,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': -5.08,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 3.31,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Hokitika',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 62.98,
#   'Humidity': 80,
#   'Cloudiness': 96,
#   'Wind Speed': 7.11,
#   'Country': 'NZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Diglur',
#   'Lat': 18.55,
#   'Lng': 77.6,
#   'Max Temp': 83.08,
#   'Humidity': 12,
#   'Cloudiness': 41,
#   'Wind Speed': 4.94,
#   'Country': 'IN',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 55.22,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 55.8,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'PT',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ravar',
#   'Lat': 31.2656,
#   'Lng': 56.8055,
#   'Max Temp': 50.09,
#   'Humidity': 28,
#   'Cloudiness': 6,
#   'Wind Speed': 6.98,
#   'Country': 'IR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Nuh',
#   'Lat': 28.1167,
#   'Lng': 77.0167,
#   'Max Temp': 66.65,
#   'Humidity': 41,
#   'Cloudiness': 2,
#   'Wind Speed': 13.31,
#   'Country': 'IN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -3.78,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vrani',
#   'Lat': 45.0383,
#   'Lng': 21.4925,
#   'Max Temp': 37.29,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'RO',
#   'Weather Description': 'clear sky'},
#  {'City': 'Trinidad',
#   'Lat': -14.8333,
#   'Lng': -64.9,
#   'Max Temp': 71.89,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 1.81,
#   'Country': 'BO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Poopo',
#   'Lat': -18.3667,
#   'Lng': -66.9667,
#   'Max Temp': 45.79,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Country': 'BO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 54.99,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 16.69,
#   'Country': 'JP',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Havoysund',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 29.28,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 16.8,
#   'Country': 'NO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 19.78,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 47.75,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 18.79,
#   'Country': 'CA',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 82.62,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 4.9,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ust-Tsilma',
#   'Lat': 65.441,
#   'Lng': 52.1498,
#   'Max Temp': 13.78,
#   'Humidity': 93,
# ...
#  {'City': 'San Vicente',
#   'Lat': -26.6167,
#   'Lng': -54.1333,
#   'Max Temp': 58.08,
#   'Humidity': 99,
#   'Cloudiness': 27,
#   'Wind Speed': 2.35,
#   'Country': 'AR',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Marau',
#   'Lat': -28.4492,
#   'Lng': -52.2,
#   'Max Temp': 60.62,
#   'Humidity': 87,
#   'Cloudiness': 67,
#   'Wind Speed': 4.9,
#   'Country': 'BR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kyzyl',
#   'Lat': 51.7,
#   'Lng': 94.45,
#   'Max Temp': -8.18,
#   'Humidity': 92,
#   'Cloudiness': 63,
#   'Wind Speed': 1.05,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kuytun',
#   'Lat': 54.3419,
#   'Lng': 101.5036,
#   'Max Temp': 0.03,
#   'Humidity': 95,
#   'Cloudiness': 78,
#   'Wind Speed': 2.71,
#   'Country': 'RU',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vilhena',
#   'Lat': -12.7406,
#   'Lng': -60.1458,
#   'Max Temp': 68.43,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Castelo Branco',
#   'Lat': 39.8222,
#   'Lng': -7.4909,
#   'Max Temp': 38.79,
#   'Humidity': 51,
#   'Cloudiness': 4,
#   'Wind Speed': 5.35,
#   'Country': 'PT',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lubango',
#   'Lat': -14.9172,
#   'Lng': 13.4925,
#   'Max Temp': 67.71,
#   'Humidity': 52,
#   'Cloudiness': 99,
#   'Wind Speed': 4.99,
#   'Country': 'AO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Erenhot',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': 11.97,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 16.89,
#   'Country': 'CN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Rylsk',
#   'Lat': 51.5655,
#   'Lng': 34.6822,
#   'Max Temp': 24.31,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 19.89,
#   'Country': 'RU',
#   'Weather Description': 'snow'},
#  {'City': 'Kambove',
#   'Lat': -10.8764,
#   'Lng': 26.5969,
#   'Max Temp': 63.93,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.43,
#   'Country': 'CD',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Vendome',
#   'Lat': 47.8,
#   'Lng': 1.0667,
#   'Max Temp': 46.09,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 5.57,
#   'Country': 'FR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Levittown',
#   'Lat': 40.1551,
#   'Lng': -74.8288,
#   'Max Temp': 13.42,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Cusco',
#   'Lat': -13.5183,
#   'Lng': -71.9781,
#   'Max Temp': 42.73,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.39,
#   'Country': 'PE',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 9.1,
#   'Humidity': 83,
#   'Cloudiness': 78,
#   'Wind Speed': 6.33,
#   'Country': 'GL',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Riyadh',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 57.34,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'SA',
#   'Weather Description': 'clear sky'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 4.66,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Penzance',
#   'Lat': 50.1186,
#   'Lng': -5.5371,
#   'Max Temp': 44.76,
#   'Humidity': 76,
#   'Cloudiness': 57,
#   'Wind Speed': 4.61,
#   'Country': 'GB',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Guasdualito',
#   'Lat': 7.2424,
#   'Lng': -70.7324,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 3.44,
#   'Country': 'VE',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Laurel',
#   'Lat': 39.0993,
#   'Lng': -76.8483,
#   'Max Temp': 19.85,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Esterhazy',
#   'Lat': 50.65,
#   'Lng': -102.0843,
#   'Max Temp': 7.65,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 85.77,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Daman',
#   'Lat': 20.4167,
#   'Lng': 72.85,
#   'Max Temp': 77.81,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 9.6,
#   'Country': 'IN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Luau',
#   'Lat': -10.7073,
#   'Lng': 22.2247,
#   'Max Temp': 72.36,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 7.76,
#   'Country': 'AO',
#   'Weather Description': 'light rain'},
#  {'City': 'Yilan',
#   'Lat': 24.757,
#   'Lng': 121.753,
#   'Max Temp': 56.55,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Country': 'TW',
#   'Weather Description': 'light rain'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 27.3,
#   'Humidity': 89,
#   'Cloudiness': 87,
#   'Wind Speed': 10,
#   'Country': 'NO',
#   'Weather Description': 'snow'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 0.99,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Weather Description': 'light snow'},
#  {'City': 'Yatou',
#   'Lat': 37.15,
#   'Lng': 122.3833,
#   'Max Temp': 34.9,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 9.55,
#   'Country': 'CN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Gondanglegi',
#   'Lat': -7.7479,
#   'Lng': 112.0132,
#   'Max Temp': 80.17,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 7.16,
#   'Country': 'ID',
#   'Weather Description': 'moderate rain'},
#  {'City': 'Rio Tercero',
#   'Lat': -32.173,
#   'Lng': -64.1141,
#   'Max Temp': 60.46,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Country': 'AR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Nabinagar',
#   'Lat': 23.8917,
#   'Lng': 90.9733,
#   'Max Temp': 75.27,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'BD',
#   'Weather Description': 'clear sky'},
#  {'City': 'Berezovyy',
#   'Lat': 51.6667,
#   'Lng': 135.7,
#   'Max Temp': 1.96,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.78,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Peleduy',
#   'Lat': 59.6289,
#   'Lng': 112.7406,
#   'Max Temp': -2.9,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Canavieiras',
#   'Lat': -15.675,
#   'Lng': -38.9472,
#   'Max Temp': 75.24,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 4.25,
#   'Country': 'BR',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Berbera',
#   'Lat': 10.4396,
#   'Lng': 45.0143,
#   'Max Temp': 78.93,
#   'Humidity': 55,
#   'Cloudiness': 98,
#   'Wind Speed': 9.31,
#   'Country': 'SO',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Luxor',
#   'Lat': 25.6989,
#   'Lng': 32.6421,
#   'Max Temp': 57.15,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 8.9,
#   'Country': 'EG',
#   'Weather Description': 'clear sky'},
#  {'City': 'Quzhou',
#   'Lat': 28.9594,
#   'Lng': 118.8686,
#   'Max Temp': 40.35,
#   'Humidity': 87,
#   'Cloudiness': 93,
#   'Wind Speed': 1.52,
#   'Country': 'CN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bayangol',
#   'Lat': 50.6977,
#   'Lng': 103.4656,
#   'Max Temp': 10.67,
#   'Humidity': 69,
#   'Cloudiness': 21,
#   'Wind Speed': 1.01,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Rio Verde De Mato Grosso',
#   'Lat': -18.9181,
#   'Lng': -54.8442,
#   'Max Temp': 69.6,
#   'Humidity': 99,
#   'Cloudiness': 84,
#   'Wind Speed': 3.98,
#   'Country': 'BR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 81.55,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 8.34,
#   'Country': 'MZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 65.66,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.21,
#   'Country': 'AR',
#   'Weather Description': 'clear sky'},
#  {'City': 'Lac Du Bonnet',
#   'Lat': 50.2536,
#   'Lng': -96.0612,
#   'Max Temp': -8.41,
#   'Humidity': 100,
#   'Cloudiness': 96,
#   'Wind Speed': 0.27,
#   'Country': 'CA',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Eenhana',
#   'Lat': -17.4667,
#   'Lng': 16.3333,
#   'Max Temp': 65.97,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 9.86,
#   'Country': 'NA',
#   'Weather Description': 'light rain'},
#  {'City': 'Socorro',
#   'Lat': 31.6546,
#   'Lng': -106.3033,
#   'Max Temp': 48.88,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 76.89,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'NU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Suoyarvi',
#   'Lat': 62.0833,
#   'Lng': 32.35,
#   'Max Temp': 18.34,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.69,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Kankan',
#   'Lat': 10.3854,
#   'Lng': -9.3057,
#   'Max Temp': 71.62,
#   'Humidity': 22,
#   'Cloudiness': 10,
#   'Wind Speed': 5.32,
#   'Country': 'GN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Payo',
#   'Lat': -3.7508,
#   'Lng': 103.6372,
#   'Max Temp': 85.69,
#   'Humidity': 72,
#   'Cloudiness': 88,
#   'Wind Speed': 3.36,
#   'Country': 'ID',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Inuvik',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp': -15.74,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'CA',
#   'Weather Description': 'light snow'},
#  {'City': 'Hendaye',
#   'Lat': 43.3717,
#   'Lng': -1.7738,
#   'Max Temp': 43.25,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'FR',
#   'Weather Description': 'mist'},
#  {'City': 'Ribeira Brava',
#   'Lat': 32.65,
#   'Lng': -17.0667,
#   'Max Temp': 63.23,
#   'Humidity': 36,
#   'Cloudiness': 5,
#   'Wind Speed': 7.87,
#   'Country': 'PT',
#   'Weather Description': 'clear sky'},
#  {'City': 'Tessalit',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 66.76,
#   'Humidity': 15,
#   'Cloudiness': 5,
#   'Wind Speed': 13.62,
#   'Country': 'ML',
#   'Weather Description': 'clear sky'},
#  {'City': 'Baijiantan',
#   'Lat': 45.6333,
#   'Lng': 85.1833,
#   'Max Temp': 11.32,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.47,
#   'Country': 'CN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 82.76,
#   'Humidity': 73,
#   'Cloudiness': 16,
#   'Wind Speed': 15.7,
#   'Country': 'MV',
#   'Weather Description': 'few clouds'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 61.81,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'NZ',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 87.48,
#   'Humidity': 58,
#   'Cloudiness': 42,
#   'Wind Speed': 8.99,
#   'Country': 'MU',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Zhangye',
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp': 23.86,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 2.55,
#   'Country': 'CN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Oleksandrivka',
#   'Lat': 48.9634,
#   'Lng': 32.2349,
#   'Max Temp': 26.96,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 20.02,
#   'Country': 'UA',
#   'Weather Description': 'light snow'},
#  {'City': 'Mezen',
#   'Lat': 65.8522,
#   'Lng': 44.24,
#   'Max Temp': 12.16,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.75,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Badou',
#   'Lat': 7.5833,
#   'Lng': 0.6,
#   'Max Temp': 78.01,
#   'Humidity': 20,
#   'Cloudiness': 100,
#   'Wind Speed': 6.38,
#   'Country': 'TG',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 95.54,
#   'Humidity': 23,
#   'Cloudiness': 10,
#   'Wind Speed': 5.23,
#   'Country': 'MG',
#   'Weather Description': 'clear sky'},
#  {'City': 'Bogande',
#   'Lat': 12.9714,
#   'Lng': -0.1436,
#   'Max Temp': 69.93,
#   'Humidity': 14,
#   'Cloudiness': 5,
#   'Wind Speed': 15.7,
#   'Country': 'BF',
#   'Weather Description': 'clear sky'},
#  {'City': 'Asosa',
#   'Lat': 10.0667,
#   'Lng': 34.5333,
#   'Max Temp': 78.96,
#   'Humidity': 25,
#   'Cloudiness': 62,
#   'Wind Speed': 2.89,
#   'Country': 'ET',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Okha',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': -5.71,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tommot',
#   'Lat': 58.9564,
#   'Lng': 126.2925,
#   'Max Temp': -1.16,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.29,
#   'Country': 'RU',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Andres',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 77.02,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'CO',
#   'Weather Description': 'few clouds'},
#  {'City': 'Kimbe',
#   'Lat': -5.5502,
#   'Lng': 150.1429,
#   'Max Temp': 78.93,
#   'Humidity': 87,
#   'Cloudiness': 91,
#   'Wind Speed': 3.36,
#   'Country': 'PG',
#   'Weather Description': 'light rain'},
#  {'City': 'Malyye Derbety',
#   'Lat': 47.9547,
#   'Lng': 44.6808,
#   'Max Temp': 32.23,
#   'Humidity': 86,
#   'Cloudiness': 86,
#   'Wind Speed': 18.75,
#   'Country': 'RU',
#   'Weather Description': 'light snow'},
#  {'City': 'Baoma',
#   'Lat': 31.4859,
#   'Lng': 106.1128,
#   'Max Temp': 49.23,
#   'Humidity': 52,
#   'Cloudiness': 99,
#   'Wind Speed': 4.9,
#   'Country': 'CN',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mingshui',
#   'Lat': 36.7167,
#   'Lng': 117.5,
#   'Max Temp': 42.57,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 1.1,
#   'Country': 'CN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Aksha',
#   'Lat': 50.2814,
#   'Lng': 113.2867,
#   'Max Temp': 7.97,
#   'Humidity': 74,
#   'Cloudiness': 15,
#   'Wind Speed': 5.44,
#   'Country': 'RU',
#   'Weather Description': 'few clouds'},
#  {'City': 'Sompeta',
#   'Lat': 18.9333,
#   'Lng': 84.6,
#   'Max Temp': 76.73,
#   'Humidity': 41,
#   'Cloudiness': 5,
#   'Wind Speed': 7.63,
#   'Country': 'IN',
#   'Weather Description': 'clear sky'},
#  {'City': 'Luan',
#   'Lat': 46.3592,
#   'Lng': 6.9759,
#   'Max Temp': 36.68,
#   'Humidity': 81,
#   'Cloudiness': 78,
#   'Wind Speed': 1.7,
#   'Country': 'CH',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Talas',
#   'Lat': 38.6908,
#   'Lng': 35.5538,
#   'Max Temp': 16.47,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'TR',
#   'Weather Description': 'broken clouds'},
#  {'City': 'Grants Pass',
#   'Lat': 42.439,
#   'Lng': -123.3284,
#   'Max Temp': 52.48,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Weather Description': 'clear sky'},
#  {'City': 'Jacareacanga',
#   'Lat': -6.2222,
#   'Lng': -57.7528,
#   'Max Temp': 70.36,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Country': 'BR',
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Davila',
#   'Lat': 18.4726,
#   'Lng': 120.5763,
#   'Max Temp': 78.78,
#   'Humidity': 79,
#   'Cloudiness': 89,
#   'Wind Speed': 18.63,
#   'Country': 'PH',
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gaoua',
#   'Lat': 10.2992,
#   'Lng': -3.2508,
#   'Max Temp': 73.56,
#   'Humidity': 17,
#   'Cloudiness': 3,
#   'Wind Speed': 8.97,
#   'Country': 'BF',
#   'Weather Description': 'clear sky'},
#  {'City': 'La Rioja',
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 33.12,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 6.22,
#   'Country': 'ES',
#   'Weather Description': 'clear sky'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 67.75,
#   'Humidity': 13,
#   'Cloudiness': 34,
#   'Wind Speed': 11.5,
#   'Country': 'ML',
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Marsabit',
#   'Lat': 2.3284,
#   'Lng': 37.9899,
#   'Max Temp': 73.29,
#   'Humidity': 52,
#   'Cloudiness': 24,
#   'Wind Speed': 16.71,
#   'Country': 'KE',
#   'Weather Description': 'few clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
df = pd.DataFrame(city_data)
df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Liverpool  53.4106   -2.9779     41.61        89          20        1.99
# 1   Nikolskoye  59.7035   30.7861     29.71        94         100       13.15
# 2      Mataura -46.1927  168.8643     61.48        93         100        2.77
# 3       Atuona  -9.8000 -139.0333     77.86        75          10       14.85
# 4       Gwadar  25.1216   62.3254     76.30        63           0       13.62
# 5    Cape Town -33.9258   18.4232     81.10        52           0        5.99
# 6      Qaanaaq  77.4840  -69.3632    -10.28        91          95        5.93
# 7     Olafsvik  64.8945  -23.7142     35.19        95         100       27.85
# 8   Novouzensk  50.4592   48.1431     31.80        96         100       16.84
# 9  Yellowknife  62.4560 -114.3525    -18.58        93          20        6.91
#
#   Country Weather Description
# 0      GB          few clouds
# 1      RU                snow
# 2      NZ     overcast clouds
# 3      PF           clear sky
# 4      PK           clear sky
# 5      ZA           clear sky
# 6      GL     overcast clouds
# 7      IS          light snow
# 8      RU          light snow
# 9      CA          few clouds

# %%
#reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Weather Description"]
city_data_df = df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Liverpool      GB  53.4106   -2.9779     41.61        89          20
# 1   Nikolskoye      RU  59.7035   30.7861     29.71        94         100
# 2      Mataura      NZ -46.1927  168.8643     61.48        93         100
# 3       Atuona      PF  -9.8000 -139.0333     77.86        75          10
# 4       Gwadar      PK  25.1216   62.3254     76.30        63           0
# 5    Cape Town      ZA -33.9258   18.4232     81.10        52           0
# 6      Qaanaaq      GL  77.4840  -69.3632    -10.28        91          95
# 7     Olafsvik      IS  64.8945  -23.7142     35.19        95         100
# 8   Novouzensk      RU  50.4592   48.1431     31.80        96         100
# 9  Yellowknife      CA  62.4560 -114.3525    -18.58        93          20
#
#    Wind Speed Weather Description
# 0        1.99          few clouds
# 1       13.15                snow
# 2        2.77     overcast clouds
# 3       14.85           clear sky
# 4       13.62           clear sky
# 5        5.99           clear sky
# 6        5.93     overcast clouds
# 7       27.85          light snow
# 8       16.84          light snow
# 9        6.91          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
